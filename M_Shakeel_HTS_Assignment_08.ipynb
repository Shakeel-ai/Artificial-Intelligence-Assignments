# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = [10,5]

import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
df = pd.read_csv("/content/USA_Housing.csv")

# %%
df.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
df.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
df.shape
# Out:
# (5000, 7)

# %% [markdown]
# **Visualization and exploring the data using seaborn**

# %%
sns.histplot(df['Price'],kde=False)
plt.show()

# %% [markdown]
# Histplot shows the price oh houses.Much houses price started from 1e+06 and end on 1.75e+06.

# %%
sns.distplot(df['Price'])
plt.show()

# %% [markdown]
# **Scatterplot**

# %%
plt.subplots(figsize=(10,8))
sns.scatterplot(x='Area Population',y='Avg. Area Income',data=df)
plt.show()

# %% [markdown]
# ## Scatterplot shows the average income of majority population is between 45000 to 85000.

# %%
sns.boxplot(df['Price'])
plt.show()

# %% [markdown]
# Boxplot shows outliers in prices of houses.

# %%
sns.regplot(x='Area Population',y='Price',data=df)
plt.show()

# %% [markdown]
# **We say that there is week connection between Area Population and Price. **

# %%
sns.regplot(x='Avg. Area Income',y='Price',data=df)
plt.show()

# %% [markdown]
# **We say that there is a some connection between Average Area Income and Pice**

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(),cmap='YlGnBu',annot=True,fmt='.3f')
plt.show()

# %% [markdown]
# # Cleaning the dataset:

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
print('training data shape :',df.shape)
# Out:
# training data shape : (5000, 7)

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
duplicated_rows = df[df.duplicated()]
print("Duplicatd Rows:",duplicated_rows.shape)
# Out:
# Duplicatd Rows: (0, 7)

# %%
df.count()
# Out:
# Avg. Area Income                5000
# Avg. Area House Age             5000
# Avg. Area Number of Rooms       5000
# Avg. Area Number of Bedrooms    5000
# Area Population                 5000
# Price                           5000
# Address                         5000
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='tab20c_r')
plt.title("Missing Data: Training Set")
plt.show()

# %%
df.drop("Address", axis =1,inplace=True)

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %% [markdown]
# # **Machine Learning**

# %% [markdown]
# **Split Target Variable**

# %%
x = df.drop('Price',axis=1)
y = df['Price']

# %%
x.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population
# 0                          4.09     23086.800503
# 1                          3.09     40173.072174
# 2                          5.13     36882.159400
# 3                          3.26     34310.242831
# 4                          4.23     26354.109472

# %%
x.shape
# Out:
# (5000, 5)

# %%
y.head(10)
# Out:
# 0    1.059034e+06
# 1    1.505891e+06
# 2    1.058988e+06
# 3    1.260617e+06
# 4    6.309435e+05
# 5    1.068138e+06
# 6    1.502056e+06
# 7    1.573937e+06
# 8    7.988695e+05
# 9    1.545155e+06
# Name: Price, dtype: float64

# %%
y.shape
# Out:
# (5000,)

# %%
y_train
# Out:
# array([[0.52556253],
#        [0.56459476],
#        [0.42097338],
#        ...,
#        [0.44298664],
#        [0.34615447],
#        [0.85296748]])

# %%
x_train.shape
# Out:
# (4000, 5)

# %%
y_train.shape
# Out:
# (4000, 1)

# %%
y_test.shape
# Out:
# (1000, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split( x,y,test_size=.20,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Scoring**

# %%
y_pred = lin_reg.predict(x_test)
print(y_pred.shape)
print(y_pred)
# Out:
# (1000,)
# [1257919.729097    822112.41884197 1740669.05865495  972452.12917494
#   993422.26329315  644126.07414456 1073911.79101682  856584.00194133
#  1445318.25518365 1204342.19071175 1455792.46212863 1298556.65696433
#  1735924.33836095 1336925.7757779  1387637.43231922 1222403.77772069
#   613786.28691982  963933.54416267 1221197.33050139 1198071.57563599
#   505861.89531673 1769106.54723353 1853881.16842511 1200369.50507868
#  1065129.1285072  1812033.73067313 1768686.47091262 1439920.83814323
#  1387251.99649376 1541178.39224181  726418.80504278 1754497.60908688
#  1462185.72653198 1025600.16081145 1284926.8685155   917454.59590853
#  1187046.94956865  999330.91117488 1329536.63409595  782191.60441437
#  1393272.03053841  578216.88394851  822643.37151048 1895533.11413226
#  1672019.8489204   966926.45434583 1129674.55638146  792797.75914663
#  1161057.18412143 1472396.71417164 1457656.70412313 1162939.334229
# ...

# %%
results = np.column_stack((y_test, y_pred))
print("Actual Values  |  Predicted Values")
print("-----------------------------")
for actual, predicted in results:
    print(f"{actual:14.2f} |  {predicted:12.2f}")
# Out:
# Actual Values  |  Predicted Values
# -----------------------------
#     1251688.62 |    1257919.73
#      873048.32 |     822112.42
#     1696977.66 |    1740669.06
#     1063964.29 |     972452.13
#      948788.28 |     993422.26
#      730043.65 |     644126.07
#     1166925.15 |    1073911.79
#      705444.12 |     856584.00
#     1499988.88 |    1445318.26
#     1288199.15 |    1204342.19
#     1441736.76 |    1455792.46
#     1279681.15 |    1298556.66
#     1754969.16 |    1735924.34
#     1511653.45 |    1336925.78
#     1441956.20 |    1387637.43
#     1119992.62 |    1222403.78
#      727866.53 |     613786.29
#     1138885.10 |     963933.54
#     1074263.32 |    1221197.33
#     1386473.37 |    1198071.58
#      404643.60 |     505861.90
#     1449829.49 |    1769106.55
#     1775874.76 |    1853881.17
#     1202050.58 |    1200369.51
#     1105737.46 |    1065129.13
#     1835564.69 |    1812033.73
#     1795428.77 |    1768686.47
#     1424283.37 |    1439920.84
# ...

# %%
residual = y_test- y_pred.reshape(-1)
print(residual)
# Out:
# 1718     -6231.113394
# 2511     50935.900800
# 345     -43691.395822
# 2521     91512.158699
# 54      -44633.987584
#             ...
# 3900      8578.803183
# 3753   -104601.289733
# 3582     38997.150646
# 2392   -155113.478325
# 3343     90915.992050
# Name: Price, Length: 1000, dtype: float64

# %%
sns.distplot(residual,kde=True)
plt.show()

# %% [markdown]
# *Mean Squared Error*

# %%
from sklearn.metrics import mean_squared_error

print('Linear Regression Model')
print('--'*30)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Linear Regression Model
# ------------------------------------------------------------
# Mean Squared Error: 10100187858.864885
# Root Mean Squared Error: 100499.69083964829

# %% [markdown]
# # Pre_processing

# %%
from sklearn import preprocessing
pre_process=preprocessing.StandardScaler().fit(x)
x_transform = pre_process.fit_transform(x)

# %%
x_transform.shape
x_transform
# Out:
# array([[ 1.02865969, -0.29692705,  0.02127433,  0.08806222, -1.31759867],
#        [ 1.00080775,  0.02590164, -0.25550611, -0.72230146,  0.40399945],
#        [-0.68462916, -0.11230283,  1.5162435 ,  0.93084045,  0.07240989],
#        ...,
#        [-0.48723454,  1.28447022, -2.17026949, -1.50025059, -0.29193658],
#        [-0.05459152, -0.44669439,  0.14154061,  1.18205319,  0.65111608],
#        [-0.28831272,  0.01521477, -0.19434166,  0.07185495,  1.04162464]])

# %% [markdown]
# **Model Training**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_transform,y,test_size=.10,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
lin_reg= LinearRegression()
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
print("Linear Regression Model")
print('--'*25)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
print("Mean Square Error",mse)
print("Root Mean Squared Error",rmse)
# Out:
# Linear Regression Model
# --------------------------------------------------
# Mean Square Error 9839952411.801708
# Root Mean Squared Error 99196.53427313732

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
y_transform = scaler.fit_transform(y.values.reshape(-1, 1))

# %%
y_transform
# Out:
# array([[0.42521032],
#        [0.60736859],
#        [0.42519175],
#        ...,
#        [0.41367241],
#        [0.48212679],
#        [0.52301078]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_transform,y_transform,test_size =.20,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
lin_reg_transfom = LinearRegression()
lin_reg_transfom.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
xy_pred = lin_reg_transfom.predict(x_test)

# %%
residual = y_test-xy_pred.reshape(-1)
print(residual)
# Out:
# [[-0.00254007  0.17511373 -0.19932945 ... -0.04644534  0.07601543
#    0.06294323]
#  [-0.15689013  0.02076366 -0.35367951 ... -0.2007954  -0.07833463
#   -0.09140684]
#  [ 0.17897889  0.35663268 -0.01781049 ...  0.13507362  0.25753439
#    0.24446219]
#  ...
#  [ 0.05980219  0.23745598 -0.13698719 ...  0.01589692  0.13835768
#    0.12528548]
#  [-0.14178642  0.03586738 -0.3385758  ... -0.18569169 -0.06323092
#   -0.07630312]
#  [-0.02842203  0.14923177 -0.22521141 ... -0.0723273   0.05013347
#    0.03706127]]

# %%
sns.distplot(residual,kde=True)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,xy_pred)

print("Linear Regressor",mse)
# Out:
# Linear Regressor 0.0016783765736029354

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)

dt_pred = dtr.predict(x_test)

D_mse = mean_squared_error(y_test,dt_pred)

print("Decision Tree Regressor",D_mse)
# Out:
# Decision Tree Regressor 0.005386791022410762

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)

rf_pred = rf.predict(x_test)

R_mse = mean_squared_error(y_test,rf_pred)

print("Random Forest Regressor",R_mse)
# Out:
# Random Forest Regressor 0.0025000630600567056

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_train)

G_pred = gbr.predict(x_test)

G_mse = mean_squared_error(y_test,G_pred)

print("Gradient Boosting Regressor",G_mse)
# Out:
# Gradient Boosting Regressor 0.0020601614308956434

# %%
model_scores = {
    "Linear Regression":0.0016783765736029354 ,
    "Descison Tree":0.0053199694560620205 ,
    "Random Forest":.00250679086500842,
    "Gradient Boosting": 0.002060253641570978
}

sorted_scores = sorted(model_scores.items(), key=lambda x: x[1])

print("Model Rankings (lower values are better):")
for rank, (model_name, score) in enumerate(sorted_scores, start=1):
    print(f"{rank}. {model_name}: {score}")
# Out:
# Model Rankings (lower values are better):
# 1. Linear Regression: 0.0016783765736029354
# 2. Gradient Boosting: 0.002060253641570978
# 3. Random Forest: 0.00250679086500842
# 4. Descison Tree: 0.0053199694560620205
